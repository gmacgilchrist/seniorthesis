# %% [markdown]
# `pip install git+https://github.com/jbusecke/cmip6_preprocessing.git`
#
# `pip install PyCO2SYS`

# %%
import xarray as xr
from cmip6_preprocessing.preprocessing import combined_preprocessing
import PyCO2SYS as pyco2 # i have to install this package through terminal for it to work
import intake
import matplotlib.pyplot as plt
import numpy as np
import warnings
import gsw
from cmip6_preprocessing.utils import google_cmip_col
from cmip6_preprocessing.postprocessing import combine_datasets
from cmip6_preprocessing.postprocessing import merge_variables

# %%
col = intake.open_esm_datastore("https://storage.googleapis.com/cmip6/pangeo-cmip6.json")

# %%
col.search(variable_id = ['dissic', 'talk']).df['source_id'].unique()
# Out:
# array(['GFDL-CM4', 'GFDL-ESM4', 'GFDL-OM4p5B', 'IPSL-CM6A-LR',
#        'CNRM-ESM2-1', 'CanESM5', 'CESM2', 'CESM2-WACCM', 'CanESM5-CanOE',
#        'UKESM1-0-LL', 'MPI-ESM-1-2-HAM', 'MPI-ESM1-2-LR', 'MPI-ESM1-2-HR',
#        'GISS-E2-1-G', 'NorESM2-LM', 'GISS-E2-1-G-CC', 'MIROC-ES2L',
#        'NorCPM1', 'NorESM1-F', 'NorESM2-MM', 'ACCESS-ESM1-5', 'CESM2-FV2',
#        'CESM2-WACCM-FV2', 'MRI-ESM2-0', 'IPSL-CM5A2-INCA', 'KIOST-ESM',
#        'EC-Earth3-CC', 'CMCC-ESM2', 'IPSL-CM6A-LR-INCA'], dtype=object)

# %%
variables = ['dissic','talk', 'so', 'thetao']
z_kwargs = {'consolidated': True, 'use_cftime': True}
query = dict(experiment_id=['historical'], 
#              table_id=['Omon'], 
             variable_id=variables,
             grid_label=['gr', 'gn'],
              source_id=['GFDL-CM4', 'GFDL-ESM4', 'GFDL-OM4p5B', 'IPSL-CM6A-LR',
                         'CNRM-ESM2-1', 'CanESM5', 'CESM2', 'CESM2-WACCM', 'CanESM5-CanOE',
                         'UKESM1-0-LL', 'MPI-ESM-1-2-HAM', 'MPI-ESM1-2-LR', 'MPI-ESM1-2-HR',
                         'GISS-E2-1-G', 'NorESM2-LM', 'GISS-E2-1-G-CC', 'MIROC-ES2L',
                         'NorCPM1', 'NorESM1-F', 'NorESM2-MM', 'ACCESS-ESM1-5', 'CESM2-FV2',
                         'CESM2-WACCM-FV2', 'MRI-ESM2-0', 'IPSL-CM5A2-INCA', 'KIOST-ESM',
                         'EC-Earth3-CC', 'CMCC-ESM2', 'IPSL-CM6A-LR-INCA']
            )


cat = col.search(**query)

# print(cat.df['source_id'].unique())
dset_dict_old = cat.to_dataset_dict(zarr_kwargs=z_kwargs, storage_options={'token': 'anon'},
                                preprocess=combined_preprocessing, aggregate=False)
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.member_id.table_id.variable_id.grid_label.zstore.dcpp_init_year.version'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1464' class='' max='1464' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1464/1464 06:19<00:00]
#     </div>
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:286: UserWarning: Found time as dimension in `lon_bounds`. Assuming this is an error and just picking the first step along that dimension.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:286: UserWarning: Found time as dimension in `lev_bounds`. Assuming this is an error and just picking the first step along that dimension.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/preprocessing.py:211: UserWarning: MIROC-ES2L: No units found for lev
#   warnings.warn(f'{ds.attrs["source_id"]}: No units found for {co}')

# %%
dd_new = merge_variables(dset_dict_old)
# Out:
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCAR.CESM2-FV2.historical.r2i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCAR.CESM2-WACCM.historical.r2i1p1f1.Omon.gn.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r7i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCAR.CESM2-WACCM.historical.r3i1p1f1.Omon.gn.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCAR.CESM2-FV2.historical.r3i1p1f1.Omon.gn.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r8i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r26i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCAR.CESM2-WACCM-FV2.historical.r3i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCAR.CESM2-WACCM-FV2.historical.r2i1p1f1.Omon.gn.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r30i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r29i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorESM2-MM.historical.r3i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r2i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCAR.CESM2-WACCM-FV2.historical.r2i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r16i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r15i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCAR.CESM2-WACCM-FV2.historical.r3i1p1f1.Omon.gn.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCAR.CESM2.historical.r10i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.IPSL.IPSL-CM6A-LR.historical.r10i1p1f1.Omon.gn.none failed to combine with :cannot compare cftime.DatetimeGregorian(1850, 1, 16, 12, 0, 0, 0) and cftime.DatetimeProlepticGregorian(1850, 1, 16, 12, 0, 0, 0) (different calendars)
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r25i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r5i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r13i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r21i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r3i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r4i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r27i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r17i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r19i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r14i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCAR.CESM2-FV2.historical.r2i1p1f1.Omon.gn.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r9i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r22i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r11i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r6i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r10i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r24i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r28i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.IPSL.IPSL-CM6A-LR.historical.r2i1p1f1.Omon.gn.none failed to combine with :indexes along dimension 'lev' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCAR.CESM2-FV2.historical.r3i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r20i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r18i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r1i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.CNRM-CERFACS.CNRM-ESM2-1.historical.r2i1p1f2.Omon.gn.none failed to combine with :cannot compare cftime.DatetimeProlepticGregorian(1850, 1, 16, 12, 0, 0, 0) and cftime.DatetimeGregorian(1850, 1, 16, 12, 0, 0, 0) (different calendars)
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r12i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")
# /srv/conda/envs/notebook/lib/python3.8/site-packages/cmip6_preprocessing/postprocessing.py:122: UserWarning: CMIP.NCC.NorCPM1.historical.r23i1p1f1.Omon.gr.none failed to combine with :indexes along dimension 'time' are not equal
#   warnings.warn(f"{cmip6_dataset_id(ds)} failed to combine with :{e}")

# %%
list(dd_new.keys())
# Out:
# ['IPSL-CM6A-LR.gn.historical.Omon.r20i1p1f1',
#  'MRI-ESM2-0.gr.historical.Omon.r2i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r17i1p1f1',
#  'NorESM2-MM.gr.historical.Omon.r2i1p1f1',
#  'MPI-ESM1-2-LR.gn.historical.Omon.r10i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r9i1p1f2',
#  'NorESM2-LM.gn.historical.Oyr.r2i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r11i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r18i1p1f1',
#  'GFDL-ESM4.gr.historical.Omon.r1i1p1f1',
#  'MRI-ESM2-0.gr.historical.Omon.r5i1p1f1',
#  'MIROC-ES2L.gn.historical.Omon.r1i1000p1f2',
#  'NorESM2-LM.gr.historical.Omon.r3i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r13i1p1f1',
#  'CESM2-WACCM.gr.historical.Omon.r2i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Odec.r25i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r5i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Odec.r8i1p1f1',
#  'CNRM-ESM2-1.gn.historical.Omon.r3i1p1f2',
#  'MPI-ESM1-2-LR.gn.historical.Omon.r3i1p1f1',
#  'CanESM5.gn.historical.Omon.r22i1p1f1',
#  'CanESM5.gn.historical.Omon.r39i1p2f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r28i1p1f1',
#  'CanESM5.gn.historical.Omon.r11i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r8i1p5f1',
#  'IPSL-CM6A-LR.gn.historical.Odec.r10i1p1f1',
#  'MPI-ESM1-2-HR.gn.historical.Omon.r5i1p1f1',
#  'CESM2.gr.historical.Oyr.r3i1p1f1',
#  'CESM2.gn.historical.Omon.r11i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Odec.r5i1p1f1',
#  'MPI-ESM1-2-HR.gn.historical.Omon.r3i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r11i1p1f1',
#  'UKESM1-0-LL.gn.historical.Omon.r7i1p1f3',
#  'CESM2.gn.historical.Oyr.r1i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r28i1p1f1',
#  'CESM2.gn.historical.Oyr.r10i1p1f1',
#  'CESM2.gr.historical.Omon.r3i1p1f1',
#  'CanESM5.gn.historical.Omon.r5i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r31i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r8i1p1f2',
#  'CanESM5.gn.historical.Omon.r29i1p2f1',
#  'CanESM5.gn.historical.Omon.r40i1p2f1',
#  'MPI-ESM1-2-HR.gn.historical.Omon.r9i1p1f1',
#  'NorCPM1.gn.historical.Omon.r4i1p1f1',
#  'MIROC-ES2L.gn.historical.Omon.r12i1p1f2',
#  'CanESM5.gn.historical.Omon.r6i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r7i1p5f1',
#  'IPSL-CM6A-LR.gn.historical.Odec.r17i1p1f1',
#  'CanESM5.gn.historical.Omon.r35i1p2f1',
#  'CESM2.gr.historical.Oyr.r6i1p1f1',
#  'MPI-ESM1-2-LR.gn.historical.Omon.r6i1p1f1',
#  'CanESM5.gn.historical.Omon.r1i1p2f1',
#  'MIROC-ES2L.gn.historical.Omon.r25i1p1f2',
#  'CESM2.gn.historical.Omon.r1i1p1f1',
#  'NorCPM1.gr.historical.Oyr.r3i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r2i1p1f2',
#  'ACCESS-ESM1-5.gn.historical.Omon.r20i1p1f1',
#  'CESM2-WACCM.gr.historical.Oyr.r3i1p1f1',
#  'MPI-ESM1-2-LR.gn.historical.Omon.r5i1p1f1',
#  'CMCC-ESM2.gn.historical.Omon.r1i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Odec.r7i1p1f1',
#  'NorCPM1.gn.historical.Omon.r8i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r9i1p1f1',
#  'CanESM5.gn.historical.Oyr.r25i1p1f1',
#  'CESM2.gn.historical.Oyr.r4i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Odec.r14i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r19i1p1f1',
#  'CESM2-FV2.gr.historical.Omon.r1i1p1f1',
#  'CESM2.gr.historical.Omon.r8i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r1i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r102i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r15i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r17i1p1f1',
#  'CanESM5.gn.historical.Omon.r23i1p1f1',
#  'MIROC-ES2L.gn.historical.Omon.r10i1p1f2',
#  'MPI-ESM1-2-HR.gn.historical.Omon.r10i1p1f1',
#  'MIROC-ES2L.gn.historical.Omon.r1i1p1f2',
#  'MIROC-ES2L.gn.historical.Omon.r2i1p1f2',
#  'CanESM5.gn.historical.Oyr.r2i1p1f1',
#  'CanESM5.gn.historical.Omon.r25i1p1f1',
#  'CanESM5.gn.historical.Omon.r8i1p2f1',
#  'NorCPM1.gr.historical.Oyr.r20i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r27i1p1f1',
#  'UKESM1-0-LL.gn.historical.Omon.r13i1p1f2',
#  'NorCPM1.gn.historical.Omon.r25i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r1i1p1f1',
#  'CanESM5.gn.historical.Oyr.r17i1p1f1',
#  'MRI-ESM2-0.gr.historical.Oyr.r1i2p1f1',
#  'MPI-ESM1-2-HR.gn.historical.Omon.r7i1p1f1',
#  'NorCPM1.gr.historical.Oyr.r24i1p1f1',
#  'CanESM5.gn.historical.Omon.r9i1p1f1',
#  'CanESM5.gn.historical.Omon.r3i1p2f1',
#  'MIROC-ES2L.gn.historical.Omon.r5i1p1f2',
#  'ACCESS-ESM1-5.gn.historical.Omon.r6i1p1f1',
#  'CanESM5.gn.historical.Omon.r10i1p1f1',
#  'CanESM5.gn.historical.Oyr.r12i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r3i1p3f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r30i1p1f1',
#  'CanESM5-CanOE.gn.historical.Omon.r1i1p2f1',
#  'CanESM5.gn.historical.Omon.r21i1p1f1',
#  'NorESM2-LM.gr.historical.Omon.r2i1p1f1',
#  'UKESM1-0-LL.gn.historical.Omon.r18i1p1f2',
#  'MIROC-ES2L.gn.historical.Omon.r6i1p1f2',
#  'ACCESS-ESM1-5.gn.historical.Omon.r27i1p1f1',
#  'GISS-E2-1-G-CC.gn.historical.Omon.r1i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r24i1p1f1',
#  'CanESM5.gn.historical.Omon.r5i1p2f1',
#  'CanESM5.gn.historical.Omon.r19i1p1f1',
#  'NorCPM1.gr.historical.Oyr.r19i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r8i1p3f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r8i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Oyr.r32i1p1f1',
#  'CanESM5.gn.historical.Oyr.r21i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r26i1p1f1',
#  'CESM2-WACCM-FV2.gn.historical.Omon.r1i1p1f1',
#  'CanESM5.gn.historical.Omon.r7i1p1f1',
#  'CESM2-FV2.gr.historical.Oyr.r2i1p1f1',
#  'CMCC-ESM2.gn.historical.Oyr.r1i1p1f1',
#  'NorCPM1.gr.historical.Oyr.r16i1p1f1',
#  'MPI-ESM1-2-LR.gn.historical.Omon.r9i1p1f1',
#  'UKESM1-0-LL.gn.historical.Omon.r8i1p1f2',
#  'CanESM5.gn.historical.Omon.r6i1p2f1',
#  'MIROC-ES2L.gn.historical.Omon.r19i1p1f2',
#  'UKESM1-0-LL.gn.historical.Omon.r19i1p1f2',
#  'NorCPM1.gn.historical.Omon.r9i1p1f1',
#  'MPI-ESM1-2-HR.gn.historical.Omon.r8i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r8i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r5i1p1f3',
#  'CanESM5.gn.historical.Oyr.r2i1p2f1',
#  'GISS-E2-1-G.gn.historical.Omon.r10i1p5f1',
#  'CESM2.gn.historical.Oyr.r3i1p1f1',
#  'CanESM5.gn.historical.Oyr.r15i1p1f1',
#  'UKESM1-0-LL.gn.historical.Omon.r2i1p1f2',
#  'GISS-E2-1-G.gn.historical.Omon.r11i1p1f2',
#  'GISS-E2-1-G.gn.historical.Omon.r7i1p1f2',
#  'NorCPM1.gn.historical.Omon.r17i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r7i1p1f1',
#  'NorCPM1.gr.historical.Oyr.r14i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r12i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r15i1p1f1',
#  'NorESM2-LM.gn.historical.Oyr.r3i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Oyr.r14i1p1f1',
#  'CESM2-FV2.gn.historical.Oyr.r2i1p1f1',
#  'CESM2.gr.historical.Omon.r2i1p1f1',
#  'CESM2-FV2.gn.historical.Omon.r1i1p1f1',
#  'CESM2-WACCM.gn.historical.Oyr.r1i1p1f1',
#  'CanESM5.gn.historical.Omon.r26i1p2f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r5i1p1f1',
#  'CanESM5.gn.historical.Oyr.r5i1p2f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r23i1p1f1',
#  'CanESM5.gn.historical.Oyr.r10i1p2f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r5i1p1f1',
#  'NorCPM1.gr.historical.Oyr.r22i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Oyr.r18i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r22i1p1f1',
#  'UKESM1-0-LL.gn.historical.Omon.r11i1p1f2',
#  'CNRM-ESM2-1.gn.historical.Omon.r6i1p1f2',
#  'MIROC-ES2L.gn.historical.Omon.r13i1p1f2',
#  'UKESM1-0-LL.gn.historical.Omon.r3i1p1f2',
#  'CanESM5-CanOE.gn.historical.Omon.r2i1p2f1',
#  'ACCESS-ESM1-5.gn.historical.Oyr.r19i1p1f1',
#  'CanESM5.gn.historical.Oyr.r7i1p2f1',
#  'CESM2.gn.historical.Omon.r6i1p1f1',
#  'CanESM5.gn.historical.Omon.r10i1p2f1',
#  'CanESM5.gn.historical.Omon.r1i1p1f1',
#  'CanESM5.gn.historical.Omon.r2i1p2f1',
#  'UKESM1-0-LL.gn.historical.Omon.r6i1p1f3',
#  'GISS-E2-1-G.gn.historical.Omon.r1i1p1f2',
#  'CESM2.gn.historical.Omon.r4i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Odec.r18i1p1f1',
#  'CanESM5.gn.historical.Omon.r33i1p2f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r29i1p1f1',
#  'CanESM5.gn.historical.Omon.r2i1p1f1',
#  'NorCPM1.gn.historical.Omon.r30i1p1f1',
#  'CESM2-FV2.gr.historical.Oyr.r1i1p1f1',
#  'NorCPM1.gr.historical.Oyr.r2i1p1f1',
#  'MIROC-ES2L.gn.historical.Omon.r9i1p1f2',
#  'CanESM5.gn.historical.Omon.r8i1p1f1',
#  'CanESM5.gn.historical.Oyr.r22i1p1f1',
#  'NorESM2-MM.gr.historical.Oyr.r2i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r22i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r7i1p1f1',
#  'NorCPM1.gn.historical.Omon.r2i1p1f1',
#  'NorCPM1.gn.historical.Omon.r3i1p1f1',
#  'UKESM1-0-LL.gn.historical.Omon.r17i1p1f2',
#  'GISS-E2-1-G.gn.historical.Omon.r4i1p1f3',
#  'MPI-ESM1-2-LR.gn.historical.Omon.r1i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Odec.r26i1p1f1',
#  'CanESM5.gn.historical.Oyr.r4i1p2f1',
#  'GISS-E2-1-G.gn.historical.Omon.r3i1p1f3',
#  'NorESM2-LM.gr.historical.Omon.r1i1p1f1',
#  'CanESM5.gn.historical.Omon.r13i1p1f1',
#  'MPI-ESM1-2-LR.gn.historical.Omon.r8i1p1f1',
#  'UKESM1-0-LL.gn.historical.Omon.r16i1p1f2',
#  'CESM2.gn.historical.Omon.r3i1p1f1',
#  'UKESM1-0-LL.gn.historical.Omon.r10i1p1f2',
#  'CESM2.gr.historical.Omon.r6i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Odec.r28i1p1f1',
#  'UKESM1-0-LL.gn.historical.Omon.r12i1p1f2',
#  'CanESM5.gn.historical.Oyr.r9i1p1f1',
#  'CanESM5.gn.historical.Omon.r27i1p2f1',
#  'IPSL-CM6A-LR.gn.historical.Odec.r3i1p1f1',
#  'MPI-ESM1-2-HR.gn.historical.Omon.r2i1p1f1',
#  'MRI-ESM2-0.gr.historical.Omon.r1i2p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r5i1p1f2',
#  'ACCESS-ESM1-5.gn.historical.Oyr.r8i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r16i1p1f1',
#  'CanESM5.gn.historical.Omon.r36i1p2f1',
#  'CanESM5.gn.historical.Oyr.r8i1p2f1',
#  'NorCPM1.gn.historical.Omon.r14i1p1f1',
#  'CanESM5.gn.historical.Omon.r38i1p2f1',
#  'CESM2.gr.historical.Oyr.r8i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r3i1p5f1',
#  'IPSL-CM6A-LR.gn.historical.Odec.r15i1p1f1',
#  'MIROC-ES2L.gn.historical.Omon.r4i1p1f2',
#  'IPSL-CM6A-LR.gn.historical.Odec.r29i1p1f1',
#  'CanESM5-CanOE.gn.historical.Oyr.r1i1p2f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r18i1p1f1',
#  'MRI-ESM2-0.gn.historical.Omon.r1i2p1f1',
#  'CESM2-WACCM.gr.historical.Omon.r1i1p1f1',
#  'NorCPM1.gr.historical.Oyr.r9i1p1f1',
#  'CESM2-WACCM-FV2.gr.historical.Oyr.r1i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r8i1p1f1',
#  'NorESM2-LM.gn.historical.Omon.r3i1p1f1',
#  'CanESM5.gn.historical.Omon.r12i1p1f1',
#  'UKESM1-0-LL.gn.historical.Omon.r9i1p1f2',
#  'NorCPM1.gr.historical.Oyr.r1i1p1f1',
#  'CanESM5.gn.historical.Oyr.r5i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Odec.r9i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r3i1p1f1',
#  'CanESM5.gn.historical.Omon.r7i1p2f1',
#  'NorCPM1.gr.historical.Oyr.r26i1p1f1',
#  'MPI-ESM1-2-LR.gn.historical.Omon.r4i1p1f1',
#  'CanESM5.gn.historical.Omon.r15i1p1f1',
#  'NorESM2-LM.gn.historical.Omon.r2i1p1f1',
#  'CNRM-ESM2-1.gn.historical.Omon.r10i1p1f2',
#  'MIROC-ES2L.gn.historical.Omon.r15i1p1f2',
#  'NorESM2-MM.gr.historical.Omon.r1i1p1f1',
#  'CanESM5.gn.historical.Omon.r24i1p1f1',
#  'CESM2-WACCM.gr.historical.Omon.r3i1p1f1',
#  'NorCPM1.gr.historical.Oyr.r18i1p1f1',
#  'CESM2-WACCM.gr.historical.Oyr.r2i1p1f1',
#  'CanESM5-CanOE.gn.historical.Omon.r3i1p2f1',
#  'CESM2.gr.historical.Omon.r4i1p1f1',
#  'NorCPM1.gn.historical.Omon.r16i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r2i1p1f3',
#  'CESM2-FV2.gr.historical.Oyr.r3i1p1f1',
#  'CESM2-WACCM.gn.historical.Oyr.r2i1p1f1',
#  'CESM2.gr.historical.Oyr.r10i1p1f1',
#  'MIROC-ES2L.gn.historical.Omon.r26i1p1f2',
#  'GISS-E2-1-G.gn.historical.Omon.r10i1p3f1',
#  'CESM2.gr.historical.Omon.r11i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r4i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r7i1p1f1',
#  'NorCPM1.gn.historical.Omon.r28i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r24i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Oyr.r10i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r10i1p1f1',
#  'CanESM5.gn.historical.Omon.r4i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Oyr.r11i1p1f1',
#  'NorCPM1.gn.historical.Omon.r15i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r9i1p5f1',
#  'MPI-ESM-1-2-HAM.gn.historical.Omon.r2i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r19i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Odec.r16i1p1f1',
#  'CanESM5.gn.historical.Omon.r34i1p2f1',
#  'NorCPM1.gn.historical.Omon.r24i1p1f1',
#  'NorCPM1.gn.historical.Omon.r27i1p1f1',
#  'CESM2.gn.historical.Omon.r10i1p1f1',
#  'NorCPM1.gn.historical.Omon.r13i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r4i1p1f1',
#  'CanESM5.gn.historical.Omon.r17i1p1f1',
#  'CNRM-ESM2-1.gn.historical.Omon.r5i1p1f2',
#  'NorCPM1.gr.historical.Oyr.r10i1p1f1',
#  'CNRM-ESM2-1.gn.historical.Omon.r1i1p1f2',
#  'CanESM5.gn.historical.Omon.r16i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r23i1p1f1',
#  'MPI-ESM1-2-HR.gn.historical.Omon.r6i1p1f1',
#  'CESM2.gn.historical.Oyr.r7i1p1f1',
#  'NorCPM1.gn.historical.Omon.r21i1p1f1',
#  'CNRM-ESM2-1.gn.historical.Omon.r4i1p1f2',
#  'NorCPM1.gn.historical.Omon.r19i1p1f1',
#  'CanESM5.gn.historical.Omon.r14i1p1f1',
#  'CanESM5.gn.historical.Oyr.r6i1p1f1',
#  'MRI-ESM2-0.gn.historical.Omon.r1i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r4i1p5f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r13i1p1f1',
#  'CanESM5.gn.historical.Oyr.r18i1p1f1',
#  'UKESM1-0-LL.gn.historical.Omon.r4i1p1f2',
#  'CanESM5.gn.historical.Oyr.r1i1p2f1',
#  'MPI-ESM1-2-HR.gn.historical.Omon.r4i1p1f1',
#  'IPSL-CM6A-LR-INCA.gn.historical.Omon.r1i1p1f1',
#  'NorCPM1.gn.historical.Omon.r12i1p1f1',
#  'NorCPM1.gn.historical.Omon.r22i1p1f1',
#  'UKESM1-0-LL.gn.historical.Omon.r5i1p1f3',
#  'IPSL-CM6A-LR.gn.historical.Odec.r11i1p1f1',
#  'CanESM5.gn.historical.Omon.r20i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r21i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Odec.r13i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Odec.r30i1p1f1',
#  'CNRM-ESM2-1.gn.historical.Omon.r8i1p1f2',
#  'GISS-E2-1-G.gn.historical.Omon.r6i1p3f1',
#  'MIROC-ES2L.gn.historical.Omon.r29i1p1f2',
#  'MPI-ESM-1-2-HAM.gn.historical.Omon.r3i1p1f1',
#  'MIROC-ES2L.gn.historical.Omon.r11i1p1f2',
#  'CanESM5.gn.historical.Oyr.r3i1p1f1',
#  'NorCPM1.gr.historical.Oyr.r11i1p1f1',
#  'MIROC-ES2L.gn.historical.Omon.r27i1p1f2',
#  'CESM2-WACCM.gn.historical.Oyr.r3i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r29i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r3i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r6i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r2i1p1f1',
#  'CanESM5.gn.historical.Omon.r37i1p2f1',
#  'ACCESS-ESM1-5.gn.historical.Oyr.r3i1p1f1',
#  'CESM2.gn.historical.Oyr.r5i1p1f1',
#  'MIROC-ES2L.gn.historical.Omon.r23i1p1f2',
#  'NorCPM1.gr.historical.Oyr.r23i1p1f1',
#  'NorCPM1.gn.historical.Omon.r18i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Odec.r20i1p1f1',
#  'CanESM5.gn.historical.Omon.r32i1p2f1',
#  'GISS-E2-1-G.gn.historical.Omon.r4i1p3f1',
#  'CESM2.gr.historical.Omon.r1i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r25i1p1f1',
#  'MIROC-ES2L.gn.historical.Omon.r8i1p1f2',
#  'NorESM2-MM.gn.historical.Omon.r3i1p1f1',
#  'NorCPM1.gn.historical.Omon.r5i1p1f1',
#  'NorCPM1.gn.historical.Omon.r29i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r12i1p1f1',
#  'NorCPM1.gr.historical.Oyr.r21i1p1f1',
#  'CESM2-WACCM-FV2.gn.historical.Oyr.r2i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r4i1p1f2',
#  'NorCPM1.gn.historical.Omon.r7i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r101i1p1f1',
#  'NorCPM1.gr.historical.Oyr.r27i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Odec.r1i1p1f1',
#  'CESM2.gr.historical.Omon.r9i1p1f1',
#  'MIROC-ES2L.gn.historical.Omon.r28i1p1f2',
#  'MRI-ESM2-0.gr.historical.Omon.r1i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r9i1p3f1',
#  'CanESM5.gn.historical.Oyr.r1i1p1f1',
#  'NorCPM1.gr.historical.Oyr.r8i1p1f1',
#  'NorESM2-MM.gn.historical.Oyr.r2i1p1f1',
#  'CESM2.gn.historical.Omon.r2i1p1f1',
#  'NorESM2-LM.gr.historical.Oyr.r3i1p1f1',
#  'CanESM5.gn.historical.Oyr.r3i1p2f1',
#  'CanESM5.gn.historical.Omon.r9i1p2f1',
#  'NorESM2-LM.gr.historical.Oyr.r2i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r1i1p3f1',
#  'GISS-E2-1-G.gn.historical.Omon.r10i1p1f2',
#  'CESM2.gr.historical.Omon.r7i1p1f1',
#  'CanESM5.gn.historical.Oyr.r23i1p1f1',
#  'CanESM5.gn.historical.Omon.r18i1p1f1',
#  'CESM2.gr.historical.Oyr.r5i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r9i1p1f1',
#  'NorCPM1.gn.historical.Omon.r20i1p1f1',
#  'CESM2.gr.historical.Oyr.r11i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r32i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r16i1p1f1',
#  'CanESM5.gn.historical.Omon.r31i1p2f1',
#  'GFDL-CM4.gr.historical.Omon.r1i1p1f1',
#  'CanESM5.gn.historical.Oyr.r16i1p1f1',
#  'NorCPM1.gr.historical.Oyr.r12i1p1f1',
#  'CESM2.gn.historical.Omon.r7i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r21i1p1f1',
#  'NorCPM1.gn.historical.Omon.r23i1p1f1',
#  'NorCPM1.gr.historical.Oyr.r15i1p1f1',
#  'CESM2.gr.historical.Omon.r5i1p1f1',
#  'CanESM5.gn.historical.Oyr.r7i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r1i1p5f1',
#  'EC-Earth3-CC.gn.historical.Oyr.r1i1p1f1',
#  'CESM2.gn.historical.Omon.r8i1p1f1',
#  'MIROC-ES2L.gn.historical.Omon.r17i1p1f2',
#  'CESM2-WACCM-FV2.gn.historical.Oyr.r3i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r25i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r30i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Oyr.r13i1p1f1',
#  'CESM2.gn.historical.Omon.r5i1p1f1',
#  'CNRM-ESM2-1.gn.historical.Omon.r7i1p1f2',
#  'ACCESS-ESM1-5.gn.historical.Oyr.r20i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r4i1p1f1',
#  'MRI-ESM2-0.gr.historical.Omon.r3i1p1f1',
#  'MPI-ESM-1-2-HAM.gn.historical.Omon.r1i1p1f1',
#  'GFDL-CM4.gn.historical.Omon.r1i1p1f1',
#  'CESM2-WACCM-FV2.gn.historical.Oyr.r1i1p1f1',
#  'MIROC-ES2L.gn.historical.Omon.r7i1p1f2',
#  'CESM2.gr.historical.Oyr.r7i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r3i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r14i1p1f1',
#  'NorCPM1.gn.historical.Omon.r26i1p1f1',
#  'CESM2-WACCM-FV2.gr.historical.Oyr.r3i1p1f1',
#  'CanESM5.gn.historical.Omon.r4i1p2f1',
#  'NorCPM1.gn.historical.Omon.r1i1p1f1',
#  'NorCPM1.gn.historical.Omon.r6i1p1f1',
#  'CanESM5-CanOE.gn.historical.Oyr.r2i1p2f1',
#  'NorCPM1.gn.historical.Omon.r11i1p1f1',
#  'CESM2-WACCM.gr.historical.Oyr.r1i1p1f1',
#  'CESM2.gn.historical.Omon.r9i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r2i1p1f1',
#  'CESM2-FV2.gn.historical.Oyr.r3i1p1f1',
#  'CanESM5.gn.historical.Omon.r28i1p2f1',
#  'MIROC-ES2L.gn.historical.Omon.r14i1p1f2',
#  'ACCESS-ESM1-5.gn.historical.Oyr.r16i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r6i1p1f1',
#  'NorESM2-MM.gn.historical.Omon.r1i1p1f1',
#  'CanESM5.gn.historical.Oyr.r24i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Odec.r12i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Oyr.r17i1p1f1',
#  'CanESM5.gn.historical.Omon.r30i1p2f1',
#  'IPSL-CM6A-LR.gn.historical.Odec.r31i1p1f1',
#  'MRI-ESM2-0.gn.historical.Oyr.r1i2p1f1',
#  'GFDL-ESM4.gn.historical.Omon.r1i1p1f1',
#  'NorESM2-MM.gn.historical.Omon.r2i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r14i1p1f1',
#  'CESM2.gr.historical.Oyr.r2i1p1f1',
#  'IPSL-CM5A2-INCA.gn.historical.Omon.r1i1p1f1',
#  'MIROC-ES2L.gn.historical.Omon.r16i1p1f2',
#  'NorCPM1.gr.historical.Oyr.r25i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r3i1p1f2',
#  'IPSL-CM6A-LR.gn.historical.Odec.r27i1p1f1',
#  'MPI-ESM1-2-LR.gn.historical.Omon.r7i1p1f1',
#  'CanESM5.gn.historical.Oyr.r8i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Odec.r22i1p1f1',
#  'MPI-ESM1-2-HR.gn.historical.Omon.r1i1p1f1',
#  'CanESM5.gn.historical.Oyr.r4i1p1f1',
#  'CanESM5.gn.historical.Oyr.r10i1p1f1',
#  'CESM2-WACCM-FV2.gr.historical.Omon.r1i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r26i1p1f1',
#  'CNRM-ESM2-1.gn.historical.Omon.r9i1p1f2',
#  'GISS-E2-1-G.gn.historical.Omon.r9i1p1f1',
#  'MIROC-ES2L.gn.historical.Omon.r18i1p1f2',
#  'CanESM5-CanOE.gn.historical.Oyr.r3i1p2f1',
#  'CanESM5.gn.historical.Omon.r3i1p1f1',
#  'CESM2.gr.historical.Oyr.r1i1p1f1',
#  'CESM2.gr.historical.Oyr.r9i1p1f1',
#  'CESM2.gn.historical.Oyr.r2i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r6i1p5f1',
#  'CESM2.gn.historical.Oyr.r9i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Odec.r4i1p1f1',
#  'MPI-ESM1-2-LR.gn.historical.Omon.r2i1p1f1',
#  'CanESM5.gn.historical.Oyr.r11i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Oyr.r15i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r10i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Odec.r6i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r2i1p5f1',
#  'UKESM1-0-LL.gn.historical.Omon.r1i1p1f2',
#  'ACCESS-ESM1-5.gn.historical.Oyr.r1i1p1f1',
#  'MIROC-ES2L.gn.historical.Omon.r30i1p1f2',
#  'IPSL-CM5A2-INCA.gn.historical.Oyr.r1i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Odec.r23i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r1i1p1f3',
#  'CanESM5.gn.historical.Oyr.r6i1p2f1',
#  'CESM2.gr.historical.Oyr.r4i1p1f1',
#  'NorESM2-LM.gn.historical.Omon.r1i1p1f1',
#  'GFDL-ESM4.gr.historical.Oyr.r1i1p1f1',
#  'MRI-ESM2-0.gn.historical.Omon.r2i1p1f1',
#  'MIROC-ES2L.gn.historical.Omon.r21i1p1f2',
#  'CanESM5.gn.historical.Oyr.r19i1p1f1',
#  'NorCPM1.gr.historical.Oyr.r17i1p1f1',
#  'CanESM5.gn.historical.Oyr.r20i1p1f1',
#  'MIROC-ES2L.gn.historical.Omon.r24i1p1f2',
#  'CESM2-WACCM.gn.historical.Omon.r1i1p1f1',
#  'NorESM2-MM.gn.historical.Oyr.r3i1p1f1',
#  'MIROC-ES2L.gn.historical.Omon.r3i1p1f2',
#  'NorESM2-MM.gr.historical.Oyr.r3i1p1f1',
#  'CESM2.gn.historical.Oyr.r6i1p1f1',
#  'CESM2-WACCM-FV2.gr.historical.Oyr.r2i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Oyr.r12i1p1f1',
#  'CanESM5.gn.historical.Oyr.r13i1p1f1',
#  'MRI-ESM2-0.gr.historical.Omon.r4i1p1f1',
#  'CanESM5.gn.historical.Oyr.r9i1p2f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r1i1p1f1',
#  'MRI-ESM2-0.gn.historical.Omon.r4i1p1f1',
#  'CESM2.gn.historical.Oyr.r8i1p1f1',
#  'NorCPM1.gr.historical.Oyr.r29i1p1f1',
#  'NorCPM1.gr.historical.Oyr.r30i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Odec.r19i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r2i1p3f1',
#  'NorCPM1.gr.historical.Oyr.r4i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r5i1p3f1',
#  'ACCESS-ESM1-5.gn.historical.Oyr.r9i1p1f1',
#  'NorCPM1.gn.historical.Omon.r10i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Oyr.r2i1p1f1',
#  'NorCPM1.gr.historical.Oyr.r28i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Odec.r24i1p1f1',
#  'CanESM5.gn.historical.Oyr.r14i1p1f1',
#  'MIROC-ES2L.gn.historical.Omon.r20i1p1f2',
#  'NorCPM1.gr.historical.Oyr.r13i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r6i1p1f2',
#  'MIROC-ES2L.gn.historical.Omon.r22i1p1f2',
#  'MRI-ESM2-0.gn.historical.Omon.r3i1p1f1',
#  'CESM2.gn.historical.Oyr.r11i1p1f1',
#  'CESM2-FV2.gn.historical.Oyr.r1i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Odec.r21i1p1f1',
#  'EC-Earth3-CC.gn.historical.Omon.r1i1p1f1',
#  'MRI-ESM2-0.gn.historical.Omon.r5i1p1f1']

# %%
dd_has_all_vars={}
for name,item in dd_new.items():
    #print(name)
    #print(item.data_vars)
    present = item.data_vars
    if all(i in present for i in variables):
        #print(name)
        dd_has_all_vars[name]=item
list(dd_has_all_vars.keys())
# Out:
# ['IPSL-CM6A-LR.gn.historical.Omon.r20i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r17i1p1f1',
#  'MPI-ESM1-2-LR.gn.historical.Omon.r10i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r18i1p1f1',
#  'GFDL-ESM4.gr.historical.Omon.r1i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r13i1p1f1',
#  'CESM2-WACCM.gr.historical.Omon.r2i1p1f1',
#  'CNRM-ESM2-1.gn.historical.Omon.r3i1p1f2',
#  'MPI-ESM1-2-LR.gn.historical.Omon.r3i1p1f1',
#  'CanESM5.gn.historical.Omon.r22i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r28i1p1f1',
#  'CanESM5.gn.historical.Omon.r11i1p1f1',
#  'CESM2.gn.historical.Omon.r11i1p1f1',
#  'MPI-ESM1-2-HR.gn.historical.Omon.r3i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r11i1p1f1',
#  'CESM2.gr.historical.Omon.r3i1p1f1',
#  'CanESM5.gn.historical.Omon.r5i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r31i1p1f1',
#  'MPI-ESM1-2-HR.gn.historical.Omon.r9i1p1f1',
#  'CanESM5.gn.historical.Omon.r6i1p1f1',
#  'MPI-ESM1-2-LR.gn.historical.Omon.r6i1p1f1',
#  'CanESM5.gn.historical.Omon.r1i1p2f1',
#  'CESM2.gn.historical.Omon.r1i1p1f1',
#  'MPI-ESM1-2-LR.gn.historical.Omon.r5i1p1f1',
#  'CMCC-ESM2.gn.historical.Omon.r1i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r9i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r19i1p1f1',
#  'CESM2-FV2.gr.historical.Omon.r1i1p1f1',
#  'CESM2.gr.historical.Omon.r8i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r102i1p1f1',
#  'CanESM5.gn.historical.Omon.r23i1p1f1',
#  'MIROC-ES2L.gn.historical.Omon.r10i1p1f2',
#  'MIROC-ES2L.gn.historical.Omon.r1i1p1f2',
#  'MIROC-ES2L.gn.historical.Omon.r2i1p1f2',
#  'CanESM5.gn.historical.Omon.r25i1p1f1',
#  'CanESM5.gn.historical.Omon.r8i1p2f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r27i1p1f1',
#  'UKESM1-0-LL.gn.historical.Omon.r13i1p1f2',
#  'IPSL-CM6A-LR.gn.historical.Omon.r1i1p1f1',
#  'CanESM5.gn.historical.Omon.r9i1p1f1',
#  'CanESM5.gn.historical.Omon.r3i1p2f1',
#  'MIROC-ES2L.gn.historical.Omon.r5i1p1f2',
#  'ACCESS-ESM1-5.gn.historical.Omon.r6i1p1f1',
#  'CanESM5.gn.historical.Omon.r10i1p1f1',
#  'CanESM5-CanOE.gn.historical.Omon.r1i1p2f1',
#  'CanESM5.gn.historical.Omon.r21i1p1f1',
#  'UKESM1-0-LL.gn.historical.Omon.r18i1p1f2',
#  'MIROC-ES2L.gn.historical.Omon.r6i1p1f2',
#  'GISS-E2-1-G-CC.gn.historical.Omon.r1i1p1f1',
#  'CanESM5.gn.historical.Omon.r5i1p2f1',
#  'CanESM5.gn.historical.Omon.r19i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r8i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r26i1p1f1',
#  'CESM2-WACCM-FV2.gn.historical.Omon.r1i1p1f1',
#  'CanESM5.gn.historical.Omon.r7i1p1f1',
#  'MPI-ESM1-2-LR.gn.historical.Omon.r9i1p1f1',
#  'CanESM5.gn.historical.Omon.r6i1p2f1',
#  'UKESM1-0-LL.gn.historical.Omon.r19i1p1f2',
#  'UKESM1-0-LL.gn.historical.Omon.r2i1p1f2',
#  'IPSL-CM6A-LR.gn.historical.Omon.r15i1p1f1',
#  'CESM2.gr.historical.Omon.r2i1p1f1',
#  'CESM2-FV2.gn.historical.Omon.r1i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r5i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r5i1p1f1',
#  'UKESM1-0-LL.gn.historical.Omon.r11i1p1f2',
#  'UKESM1-0-LL.gn.historical.Omon.r3i1p1f2',
#  'CanESM5-CanOE.gn.historical.Omon.r2i1p2f1',
#  'CESM2.gn.historical.Omon.r6i1p1f1',
#  'CanESM5.gn.historical.Omon.r10i1p2f1',
#  'CanESM5.gn.historical.Omon.r1i1p1f1',
#  'CanESM5.gn.historical.Omon.r2i1p2f1',
#  'CESM2.gn.historical.Omon.r4i1p1f1',
#  'CanESM5.gn.historical.Omon.r2i1p1f1',
#  'MIROC-ES2L.gn.historical.Omon.r9i1p1f2',
#  'CanESM5.gn.historical.Omon.r8i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r22i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r7i1p1f1',
#  'UKESM1-0-LL.gn.historical.Omon.r17i1p1f2',
#  'MPI-ESM1-2-LR.gn.historical.Omon.r1i1p1f1',
#  'NorESM2-LM.gr.historical.Omon.r1i1p1f1',
#  'CanESM5.gn.historical.Omon.r13i1p1f1',
#  'MPI-ESM1-2-LR.gn.historical.Omon.r8i1p1f1',
#  'UKESM1-0-LL.gn.historical.Omon.r16i1p1f2',
#  'CESM2.gn.historical.Omon.r3i1p1f1',
#  'CESM2.gr.historical.Omon.r6i1p1f1',
#  'UKESM1-0-LL.gn.historical.Omon.r12i1p1f2',
#  'MRI-ESM2-0.gr.historical.Omon.r1i2p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r16i1p1f1',
#  'MIROC-ES2L.gn.historical.Omon.r4i1p1f2',
#  'CESM2-WACCM.gr.historical.Omon.r1i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r8i1p1f1',
#  'CanESM5.gn.historical.Omon.r12i1p1f1',
#  'UKESM1-0-LL.gn.historical.Omon.r9i1p1f2',
#  'CanESM5.gn.historical.Omon.r7i1p2f1',
#  'MPI-ESM1-2-LR.gn.historical.Omon.r4i1p1f1',
#  'CanESM5.gn.historical.Omon.r15i1p1f1',
#  'CanESM5.gn.historical.Omon.r24i1p1f1',
#  'CESM2-WACCM.gr.historical.Omon.r3i1p1f1',
#  'CanESM5-CanOE.gn.historical.Omon.r3i1p2f1',
#  'CESM2.gr.historical.Omon.r4i1p1f1',
#  'CESM2.gr.historical.Omon.r11i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r24i1p1f1',
#  'CanESM5.gn.historical.Omon.r4i1p1f1',
#  'MPI-ESM-1-2-HAM.gn.historical.Omon.r2i1p1f1',
#  'CESM2.gn.historical.Omon.r10i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r4i1p1f1',
#  'CanESM5.gn.historical.Omon.r17i1p1f1',
#  'CNRM-ESM2-1.gn.historical.Omon.r5i1p1f2',
#  'CNRM-ESM2-1.gn.historical.Omon.r1i1p1f2',
#  'CanESM5.gn.historical.Omon.r16i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r23i1p1f1',
#  'CNRM-ESM2-1.gn.historical.Omon.r4i1p1f2',
#  'CanESM5.gn.historical.Omon.r14i1p1f1',
#  'UKESM1-0-LL.gn.historical.Omon.r5i1p1f3',
#  'CanESM5.gn.historical.Omon.r20i1p1f1',
#  'CNRM-ESM2-1.gn.historical.Omon.r8i1p1f2',
#  'IPSL-CM6A-LR.gn.historical.Omon.r29i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r6i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r2i1p1f1',
#  'CESM2.gr.historical.Omon.r1i1p1f1',
#  'MIROC-ES2L.gn.historical.Omon.r8i1p1f2',
#  'IPSL-CM6A-LR.gn.historical.Omon.r12i1p1f1',
#  'GISS-E2-1-G.gn.historical.Omon.r101i1p1f1',
#  'CESM2.gr.historical.Omon.r9i1p1f1',
#  'CESM2.gn.historical.Omon.r2i1p1f1',
#  'CanESM5.gn.historical.Omon.r9i1p2f1',
#  'CESM2.gr.historical.Omon.r7i1p1f1',
#  'CanESM5.gn.historical.Omon.r18i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r9i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r32i1p1f1',
#  'GFDL-CM4.gr.historical.Omon.r1i1p1f1',
#  'CESM2.gn.historical.Omon.r7i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r21i1p1f1',
#  'CESM2.gr.historical.Omon.r5i1p1f1',
#  'CESM2.gn.historical.Omon.r8i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r25i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r30i1p1f1',
#  'CESM2.gn.historical.Omon.r5i1p1f1',
#  'ACCESS-ESM1-5.gn.historical.Omon.r4i1p1f1',
#  'MPI-ESM-1-2-HAM.gn.historical.Omon.r1i1p1f1',
#  'MIROC-ES2L.gn.historical.Omon.r7i1p1f2',
#  'IPSL-CM6A-LR.gn.historical.Omon.r3i1p1f1',
#  'IPSL-CM6A-LR.gn.historical.Omon.r14i1p1f1',
#  'CanESM5.gn.historical.Omon.r4i1p2f1',
#  'CESM2.gn.historical.Omon.r9i1p1f1',
#  'MPI-ESM1-2-LR.gn.historical.Omon.r7i1p1f1',
#  'CESM2-WACCM-FV2.gr.historical.Omon.r1i1p1f1',
#  'CNRM-ESM2-1.gn.historical.Omon.r9i1p1f2',
#  'CanESM5.gn.historical.Omon.r3i1p1f1',
#  'MPI-ESM1-2-LR.gn.historical.Omon.r2i1p1f1',
#  'UKESM1-0-LL.gn.historical.Omon.r1i1p1f2',
#  'CESM2-WACCM.gn.historical.Omon.r1i1p1f1',
#  'MIROC-ES2L.gn.historical.Omon.r3i1p1f2',
#  'ACCESS-ESM1-5.gn.historical.Omon.r1i1p1f1']

# %%
def pick_first_member(ds_list, **kwargs):
    return ds_list[0]

dd_new_new = combine_datasets(
    dd_has_all_vars,
    pick_first_member,
    match_attrs=['source_id', 'grid_label', 'experiment_id', 'table_id']
)
list(dd_new_new.keys())
# Out:
# ['IPSL-CM6A-LR.gn.historical.Omon',
#  'MPI-ESM1-2-LR.gn.historical.Omon',
#  'GFDL-ESM4.gr.historical.Omon',
#  'CESM2-WACCM.gr.historical.Omon',
#  'CNRM-ESM2-1.gn.historical.Omon',
#  'CanESM5.gn.historical.Omon',
#  'CESM2.gn.historical.Omon',
#  'MPI-ESM1-2-HR.gn.historical.Omon',
#  'CESM2.gr.historical.Omon',
#  'CMCC-ESM2.gn.historical.Omon',
#  'CESM2-FV2.gr.historical.Omon',
#  'GISS-E2-1-G.gn.historical.Omon',
#  'MIROC-ES2L.gn.historical.Omon',
#  'UKESM1-0-LL.gn.historical.Omon',
#  'ACCESS-ESM1-5.gn.historical.Omon',
#  'CanESM5-CanOE.gn.historical.Omon',
#  'GISS-E2-1-G-CC.gn.historical.Omon',
#  'CESM2-WACCM-FV2.gn.historical.Omon',
#  'CESM2-FV2.gn.historical.Omon',
#  'NorESM2-LM.gr.historical.Omon',
#  'MRI-ESM2-0.gr.historical.Omon',
#  'MPI-ESM-1-2-HAM.gn.historical.Omon',
#  'GFDL-CM4.gr.historical.Omon',
#  'CESM2-WACCM-FV2.gr.historical.Omon',
#  'CESM2-WACCM.gn.historical.Omon']

# %%
dd_gr={}
for name,item in dd_new_new.items():
    #print(name)
    #print(item.data_vars)
    if item.grid_label == 'gr':
        #print(name)
        dd_gr[name]=item
list(dd_gr.keys())
# Out:
# ['GFDL-ESM4.gr.historical.Omon',
#  'CESM2-WACCM.gr.historical.Omon',
#  'CESM2.gr.historical.Omon',
#  'CESM2-FV2.gr.historical.Omon',
#  'NorESM2-LM.gr.historical.Omon',
#  'MRI-ESM2-0.gr.historical.Omon',
#  'GFDL-CM4.gr.historical.Omon',
#  'CESM2-WACCM-FV2.gr.historical.Omon']

# %%
dd_gn={}
for name,item in dd_new_new.items():
    #print(name)
    #print(item.data_vars)
    if item.grid_label == 'gn':
        #print(name)
        dd_gn[name]=item
list(dd_gn.keys())
# Out:
# ['IPSL-CM6A-LR.gn.historical.Omon',
#  'MPI-ESM1-2-LR.gn.historical.Omon',
#  'CNRM-ESM2-1.gn.historical.Omon',
#  'CanESM5.gn.historical.Omon',
#  'CESM2.gn.historical.Omon',
#  'MPI-ESM1-2-HR.gn.historical.Omon',
#  'CMCC-ESM2.gn.historical.Omon',
#  'GISS-E2-1-G.gn.historical.Omon',
#  'MIROC-ES2L.gn.historical.Omon',
#  'UKESM1-0-LL.gn.historical.Omon',
#  'ACCESS-ESM1-5.gn.historical.Omon',
#  'CanESM5-CanOE.gn.historical.Omon',
#  'GISS-E2-1-G-CC.gn.historical.Omon',
#  'CESM2-WACCM-FV2.gn.historical.Omon',
#  'CESM2-FV2.gn.historical.Omon',
#  'MPI-ESM-1-2-HAM.gn.historical.Omon',
#  'CESM2-WACCM.gn.historical.Omon']

# %%
list(dd_gr.keys())
# Out:
# ['GFDL-ESM4.gr.historical.Omon',
#  'CESM2-WACCM.gr.historical.Omon',
#  'CESM2.gr.historical.Omon',
#  'CESM2-FV2.gr.historical.Omon',
#  'NorESM2-LM.gr.historical.Omon',
#  'MRI-ESM2-0.gr.historical.Omon',
#  'GFDL-CM4.gr.historical.Omon',
#  'CESM2-WACCM-FV2.gr.historical.Omon']

# %% [markdown]
# `'GFDL-ESM4', 'CESM2-WACCM', 'CESM2', 'CESM2-FV2', 'NorESM2-LM', 'MRI-ESM2-0', 'GFDL-CM4', 'CESM2-WACCM-FV2'`
