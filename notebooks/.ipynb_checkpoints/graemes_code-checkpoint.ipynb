# %% [markdown]
# taken from gmacgilchrist/cmip6/dev_cmip6.ipynb <br>
# idk why pyco2 isn't importing

# %%
import xarray as xr
from cmip6_preprocessing.preprocessing import combined_preprocessing
# import PyCO2SYS as pyco2 # ModuleNotFoundError: No module named 'PyCO2SYS'
import intake
import matplotlib.pyplot as plt
import numpy as np
import warnings
import gsw
warnings.filterwarnings("ignore")

# %% [markdown]
# source_id = the model <br>
# table_id = occean monthly, ocean year, etc. <br>
# what is the grid label? gn? gr? <br>

# %%
url = "https://raw.githubusercontent.com/NCAR/intake-esm-datastore/master/catalogs/pangeo-cmip6.json"
col = intake.open_esm_datastore(url)
col.df.head()
# Out:
#   activity_id institution_id     source_id       experiment_id member_id  \
# 0  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 1  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 2  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 3  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 4  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
#
#   table_id variable_id grid_label  \
# 0     Amon        huss         gn
# 1     Amon         hus         gn
# 2     Amon        rlds         gn
# 3     Amon         psl         gn
# 4     Amon          ps         gn
#
#                                               zstore  dcpp_init_year   version
# 0  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 1  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 2  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 3  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 4  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706

# %%
col.df.tail()
# Out:
#        activity_id institution_id source_id experiment_id  member_id table_id  \
# 501651      LS3MIP        RUBISCO  E3SM-1-1     land-hist  r1i1p11f1     Amon
# 501652      LS3MIP        RUBISCO  E3SM-1-1     land-hist  r1i1p11f1     Emon
# 501653      LS3MIP        RUBISCO  E3SM-1-1     land-hist  r1i1p11f1     Lmon
# 501654      LS3MIP        RUBISCO  E3SM-1-1     land-hist  r1i1p11f1     Lmon
# 501655      LS3MIP        RUBISCO  E3SM-1-1     land-hist  r1i1p11f1     Lmon
#
#        variable_id grid_label  \
# 501651         tas         gn
# 501652       mrsol         gn
# 501653     cLitter         gn
# 501654        cVeg         gn
# 501655        mrro         gn
#
#                                                    zstore  dcpp_init_year  \
# 501651  gs://cmip6/CMIP6/LS3MIP/RUBISCO/E3SM-1-1/land-...             NaN
# 501652  gs://cmip6/CMIP6/LS3MIP/RUBISCO/E3SM-1-1/land-...             NaN
# 501653  gs://cmip6/CMIP6/LS3MIP/RUBISCO/E3SM-1-1/land-...             NaN
# 501654  gs://cmip6/CMIP6/LS3MIP/RUBISCO/E3SM-1-1/land-...             NaN
# 501655  gs://cmip6/CMIP6/LS3MIP/RUBISCO/E3SM-1-1/land-...             NaN
#
#          version
# 501651  20210507
# 501652  20210507
# 501653  20210507
# 501654  20210507
# 501655  20210507

# %%
# what i think this is doing is just identifying all the unique source_IDs, 
# which i think is the name of each model
col.unique(columns='source_id')
# Out:
# {'source_id': {'count': 86,
#   'values': ['HadGEM3-GC31-HM',
#    'EC-Earth3-AerChem',
#    'NESM3',
#    'AWI-CM-1-1-MR',
#    'INM-CM5-0',
#    'MCM-UA-1-0',
#    'MIROC-ES2H',
#    'GISS-E2-1-H',
#    'EC-Earth3-Veg-LR',
#    'CNRM-ESM2-1',
#    'MIROC6',
#    'UKESM1-0-LL',
#    'AWI-ESM-1-1-LR',
#    'GFDL-OM4p5B',
#    'MPI-ESM1-2-XR',
#    'FGOALS-f3-L',
#    'E3SM-1-1',
#    'EC-Earth3-LR',
#    'EC-Earth3P-HR',
#    'GFDL-CM4C192',
#    'ACCESS-ESM1-5',
#    'BCC-CSM2-HR',
#    'ACCESS-CM2',
#    'GFDL-ESM4',
#    'CMCC-CM2-SR5',
#    'GISS-E2-1-G',
#    'FGOALS-f3-H',
#    'CESM1-1-CAM5-CMIP5',
#    'GFDL-AM4',
#    'NorESM2-LM',
#    'CESM1-WACCM-SC',
#    'CESM2-WACCM-FV2',
#    'CMCC-CM2-HR4',
#    'IPSL-CM6A-LR',
#    'MPI-ESM-1-2-HAM',
#    'EC-Earth3P',
#    'CMCC-CM2-VHR4',
#    'CNRM-CM6-1',
#    'CanESM5-CanOE',
#    'GFDL-ESM2M',
#    'EC-Earth3-CC',
#    'CESM2-WACCM',
#    'SAM0-UNICON',
#    'ECMWF-IFS-HR',
#    'CMCC-ESM2',
#    'IPSL-CM6A-LR-INCA',
#    'CanESM5',
#    'IPSL-CM5A2-INCA',
#    'MRI-ESM2-0',
#    'EC-Earth3P-VHR',
#    'NorESM2-MM',
#    'GISS-E2-2-G',
#    'HadGEM3-GC31-MM',
#    'IPSL-CM6A-ATM-HR',
#    'HadGEM3-GC31-LM',
#    'CNRM-CM6-1-HR',
#    'CAS-ESM2-0',
#    'CESM2',
#    'BCC-ESM1',
#    'MRI-AGCM3-2-S',
#    'GFDL-CM4',
#    'GISS-E2-1-G-CC',
#    'KACE-1-0-G',
#    'INM-CM4-8',
#    'MIROC-ES2L',
#    'IITM-ESM',
#    'INM-CM5-H',
#    'HadGEM3-GC31-LL',
#    'FIO-ESM-2-0',
#    'TaiESM1',
#    'E3SM-1-1-ECA',
#    'MPI-ESM1-2-LR',
#    'MPI-ESM1-2-HR',
#    'EC-Earth3',
#    'CESM2-FV2',
#    'EC-Earth3-Veg',
#    'NorCPM1',
#    'BCC-CSM2-MR',
#    'ECMWF-IFS-LR',
#    'CIESM',
#    'FGOALS-g3',
#    'MRI-AGCM3-2-H',
#    'NorESM1-F',
#    'E3SM-1-0',
#    'KIOST-ESM',
#    'CAMS-CSM1-0']}}

# %%
# giving me the unique variables for GFDL-CM4, CMIP, pre-industrial control, for monthly ocean and yearly ocean
col.search(source_id='GFDL-CM4',activity_id='CMIP',experiment_id='piControl',table_id=['Omon','Oyr']).unique(columns='variable_id')
# presumably I can do this for every model i need to identify some vars
# Out:
# {'variable_id': {'count': 56,
#   'values': ['bddtdic',
#    'pbo',
#    'po4',
#    'thetao',
#    'pp',
#    'talk',
#    'expc',
#    'mlotstmin',
#    'phyp',
#    'dissic',
#    'thetaoga',
#    'bddtdip',
#    'sos',
#    'dcalc',
#    'o2',
#    'zossq',
#    'volcello',
#    'pso',
#    'bddtalk',
#    'bddtdife',
#    'zos',
#    'evs',
#    'msftyzsmpa',
#    'fescav',
#    'sosga',
#    'dissoc',
#    'mlotst',
#    'tob',
#    'so',
#    'friver',
#    'tos',
#    'co3satcalc',
#    'mfo',
#    'msftyrho',
#    'mlotstmax',
#    'remoc',
#    'chl',
#    'sob',
#    'co3',
#    'msftyz',
#    'expcalc',
#    'ph',
#    'expp',
#    'soga',
#    'volo',
#    'pcalc',
#    'phyc',
#    'pbfe',
#    'wmo',
#    'masso',
#    'hfds',
#    'wfo',
#    'dfe',
#    'zostoga',
#    'graz',
#    'expfe']}}

# %% [markdown]
# dissic: dissolved inorganic carbon <br>
# thetao: potential temp <br>
# so: salinity <br>

# %%
variables = ['dissic','talk','so','thetao']
z_kwargs = {'consolidated': True, 'decode_times':False} # idk what this does
query = dict(experiment_id=['piControl'], table_id=['Omon'], 
             variable_id=variables,
             grid_label=['gn','gr'],
             source_id=['CanESM5-CanOE', 'CanESM5', 'ACCESS-ESM1-5',
                        'MPI-ESM-1-2-HAM', 'IPSL-CM6A-LR', 'MIROC-ES2L',
                        'MPI-ESM1-2-HR', 'MPI-ESM1-2-LR', 'NorCPM1',
                        'NorESM1-F', 'NorESM2-LM', 'NorESM2-MM', 'GFDL-ESM4'])

# %%
cat = col.search(**query)
# print(cat.df['source_id'].unique())
dset_dict = cat.to_dataset_dict(zarr_kwargs=z_kwargs,
                                preprocess=combined_preprocessing)
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='7' class='' max='16' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       43.75% [7/16 00:07<00:10]
#     </div>
# MIROC-ES2L: No units found
# MIROC-ES2L: No units found
# MIROC-ES2L: No units found
# MIROC-ES2L: No units found

# %% [markdown]
#  #### Graeme's output <br>
#
#
# --> The keys in the returned dictionary of datasets are constructed as follows: <br>
# > 'activity_id.institution_id.source_id.experiment_id.table_id.grid_label' <br>
#
# 100.00% [13/13 00:08<00:00]<br>
# *why 13/13 when mine in xx/16*
# <br><br>
#
# MIROC-ES2L: No units found<br>
# MIROC-ES2L: No units found<br>
# MIROC-ES2L: No units found<br>
# MIROC-ES2L: No units found<br>
# <br>
# #### abby's issues
#
# why is this taking forever/timing out???

# %%
temp={}
for name,item in dset_dict.items():
#     print(name)
#     print(item.data_vars)
    present = item.data_vars
    if all(i in present for i in variables):
        temp[name]=dset_dict[name] # what does this do
dset_dict = temp
dset_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4442cc6dcad8> in <module>
#       1 temp={}
# ----> 2 for name,item in dset_dict.items():
#       3 #     print(name)
#       4 #     print(item.data_vars)
#       5     present = item.data_vars
#
# NameError: name 'dset_dict' is not defined
